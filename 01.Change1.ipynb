# %%
import pandas as pd

# %%
data = pd.read_csv('PMChallenge2018/challenge1-train.txt', header=None, sep='\t')

# %%
data.shape
# Out:
# (9946, 108)

# %%
data.describe()
# Out:
#                0            4            5            6            8    \
# count  9946.000000  9946.000000  9946.000000  9946.000000  9946.000000
# mean     36.650416    49.620953    49.303036    49.874522    49.567967
# std      29.570969    28.827524    28.873557    28.691896    28.784060
# min       0.833976     0.000000     0.000000     0.000000     0.000000
# 25%       9.924151    25.000000    24.000000    25.000000    24.000000
# 50%      27.988522    50.000000    49.000000    50.000000    50.000000
# 75%      59.363603    75.000000    74.750000    74.000000    74.000000
# max     107.889839    99.000000    99.000000    99.000000    99.000000
#
#                9            10           11           12           13   \
# count  9946.000000  9946.000000  9946.000000  9946.000000  9946.000000
# mean     49.536698    49.823044    49.369998    49.622562    49.919566
# std      28.814396    28.770908    28.841552    28.949010    29.026604
# ...

# %%
data.head(100)
# Out:
#            0      1      2      3    4    5    6    \
# 0    45.437887   four  seven  seven   88   62   37
# 1     6.804464   nine    two  eight   82   14   12
# 2    18.096237    two    one  three    7   38   72
# 3    81.498121    six   zero    one   20   88   53
# 4    99.978597   zero   nine  three   76   99   96
# 5    28.508904  three  three  eight   14   52    3
# 6    84.958431  seven   four  eight   15   92   46
# 7    11.216034    two    six   four   37   28   25
# 8     2.780187   zero   five   four   91    0   55
# 9     7.337206   nine    two  seven   19   21   67
# 10    2.137017   zero  three  eight   50    3   39
# 11   93.147629  seven   nine   nine   19   95   66
# 12   18.185889   zero  seven  eight   81   36    2
# 13    4.948136  seven  seven    one    6   16   61
# 14    4.878532    six    two   nine   72    6   17
# 15    3.564780   five   four  seven   59   10   64
# 16   94.713870   nine    six   four   24   95   33
# ...
